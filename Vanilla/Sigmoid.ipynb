# %%
import sys
print(sys.path)
# Out:
# ['/usr/local/lib/python311.zip', '/usr/local/lib/python3.11', '/usr/local/lib/python3.11/lib-dynload', '', '/home/vscode/.local/lib/python3.11/site-packages', '/usr/local/lib/python3.11/site-packages']

# %%
import os
sys.path.append(os.path.abspath(".."))

# %%
import importlib
from resources import psiBfield

importlib.reload(psiBfield)

g = psiBfield.extract_g()
psi_norm, BR, Bphi, BZ = psiBfield.compute_B(g)
# Out:
# g_file keywords extracted
# Psi Normalized and Magnetic field BR Bphi BZ computed.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed_all(42)

# %%
g.r_grid
# Out:
# array([[0.84      , 0.84      , 0.84      , ..., 0.84      , 0.84      ,
#         0.84      ],
#        [0.85328125, 0.85328125, 0.85328125, ..., 0.85328125, 0.85328125,
#         0.85328125],
#        [0.8665625 , 0.8665625 , 0.8665625 , ..., 0.8665625 , 0.8665625 ,
#         0.8665625 ],
#        ...,
#        [2.5134375 , 2.5134375 , 2.5134375 , ..., 2.5134375 , 2.5134375 ,
#         2.5134375 ],
#        [2.52671875, 2.52671875, 2.52671875, ..., 2.52671875, 2.52671875,
#         2.52671875],
#        [2.54      , 2.54      , 2.54      , ..., 2.54      , 2.54      ,
#         2.54      ]], shape=(129, 129))

# %%
r = np.concatenate(g.r_grid)
print(r.shape)
# Out:
# (16641,)

# %%
z = np.concatenate(g.z_grid)
X_train = np.column_stack((r, z))
Y_train = np.concatenate(psi_norm)
BR_train  = np.concatenate(BR)
BZ_train = np.concatenate(BZ)

# %%
# NN
class PsiNN(nn.Module):
  def __init__(self):
    super(PsiNN, self).__init__()
    self.model = nn.Sequential(
        nn.Linear(2, 512),
        nn.Sigmoid(),
        nn.Linear(512, 512),
        nn.Sigmoid(),
        nn.Linear(512, 1)

    )
  def forward(self, x):
    return self.model(x)

# %%
# Initialize model, loss, and optimizer
model_psi = PsiNN()
fn_Loss = nn.MSELoss()
model_psi.to(device)
optimizer = optim.Adam(model_psi.parameters(), lr=0.001)

# %%
Y_train.dtype
# Out:
# dtype('float64')

# %%
Y_train = Y_train.reshape(-1,1)
Y_train.shape
# Out:
# (16641, 1)

# %%
# Move X_train to the device as well
X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
# Move y_train to the device as well
Y_train = torch.tensor(Y_train, dtype=torch.float32).to(device)

# Training loop
epochs = 10001
for epoch in range(epochs):
  model_psi.train()
  Y_preds = model_psi(X_train)
  loss = fn_Loss(Y_preds, Y_train)
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

  if epoch % 100 == 0:
    print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 0.17250783741474152
# Epoch 100, Loss: 0.026788627728819847
# Epoch 200, Loss: 0.025261398404836655
# Epoch 300, Loss: 0.02231883443892002
# Epoch 400, Loss: 0.019027087837457657
# Epoch 500, Loss: 0.017937559634447098
# Epoch 600, Loss: 0.017403094097971916
# Epoch 700, Loss: 0.01672530546784401
# Epoch 800, Loss: 0.0146320266649127
# Epoch 900, Loss: 0.009195142425596714
# Epoch 1000, Loss: 0.007049831096082926
# Epoch 1100, Loss: 0.006324514746665955
# Epoch 1200, Loss: 0.005684609059244394
# Epoch 1300, Loss: 0.005508079193532467
# Epoch 1400, Loss: 0.005171746015548706
# Epoch 1500, Loss: 0.004933719988912344
# Epoch 1600, Loss: 0.007311035413295031
# Epoch 1700, Loss: 0.004566705785691738
# Epoch 1800, Loss: 0.004372698720544577
# Epoch 1900, Loss: 0.004171996843069792
# Epoch 2000, Loss: 0.014261881820857525
# Epoch 2100, Loss: 0.00389858172275126
# Epoch 2200, Loss: 0.0037445337511599064
# Epoch 2300, Loss: 0.003593276720494032
# Epoch 2400, Loss: 0.0034451524261385202
# Epoch 2500, Loss: 0.003459765575826168
# Epoch 2600, Loss: 0.0033414780627936125
# Epoch 2700, Loss: 0.00323249283246696
# Epoch 2800, Loss: 0.00312609551474452
# Epoch 2900, Loss: 0.0030205969233065844
# Epoch 3000, Loss: 0.0029156452510505915
# Epoch 3100, Loss: 0.002940261736512184
# Epoch 3200, Loss: 0.0028442905750125647
# Epoch 3300, Loss: 0.0027550985105335712
# Epoch 3400, Loss: 0.002669215900823474
# Epoch 3500, Loss: 0.002585440641269088
# Epoch 3600, Loss: 0.002617357764393091
# Epoch 3700, Loss: 0.002526269294321537
# Epoch 3800, Loss: 0.0024488442577421665
# Epoch 3900, Loss: 0.002373839495703578
# Epoch 4000, Loss: 0.015840714797377586
# Epoch 4100, Loss: 0.0023340974003076553
# Epoch 4200, Loss: 0.002246452495455742
# Epoch 4300, Loss: 0.0021674528252333403
# Epoch 4400, Loss: 0.00208727503195405
# Epoch 4500, Loss: 0.034580014646053314
# Epoch 4600, Loss: 0.0020209711510688066
# Epoch 4700, Loss: 0.001925396267324686
# Epoch 4800, Loss: 0.0018382745329290628
# Epoch 4900, Loss: 0.001750044641084969
# Epoch 5000, Loss: 0.0032674940302968025
# Epoch 5100, Loss: 0.001647475059144199
# Epoch 5200, Loss: 0.0015550748212262988
# Epoch 5300, Loss: 0.0014679643791168928
# Epoch 5400, Loss: 0.0013815128477290273
# Epoch 5500, Loss: 0.0016766390763223171
# Epoch 5600, Loss: 0.001262896810658276
# Epoch 5700, Loss: 0.0011863274266943336
# Epoch 5800, Loss: 0.001115804654546082
# Epoch 5900, Loss: 0.001049684127792716
# Epoch 6000, Loss: 0.0010291937505826354
# Epoch 6100, Loss: 0.0009661251096986234
# Epoch 6200, Loss: 0.0009179070475511253
# Epoch 6300, Loss: 0.0008749666158109903
# Epoch 6400, Loss: 0.014310869388282299
# Epoch 6500, Loss: 0.0008227627840824425
# Epoch 6600, Loss: 0.0007889840635471046
# Epoch 6700, Loss: 0.0007621812401339412
# Epoch 6800, Loss: 0.0007382543408311903
# Epoch 6900, Loss: 0.0007522510131821036
# Epoch 7000, Loss: 0.0007087296689860523
# Epoch 7100, Loss: 0.0006893872050568461
# Epoch 7200, Loss: 0.0006740272510796785
# Epoch 7300, Loss: 0.0006600172491744161
# Epoch 7400, Loss: 0.0018896800465881824
# Epoch 7500, Loss: 0.000641897669993341
# Epoch 7600, Loss: 0.0006303258123807609
# Epoch 7700, Loss: 0.000620642036665231
# Epoch 7800, Loss: 0.0006115732830949128
# Epoch 7900, Loss: 0.0006638689083047211
# Epoch 8000, Loss: 0.0006002268055453897
# Epoch 8100, Loss: 0.0005926183075644076
# Epoch 8200, Loss: 0.0005859110970050097
# Epoch 8300, Loss: 0.0005795316537842155
# Epoch 8400, Loss: 0.0009152478305622935
# Epoch 8500, Loss: 0.0005712180281989276
# Epoch 8600, Loss: 0.000564645801205188
# Epoch 8700, Loss: 0.0005594086833298206
# Epoch 8800, Loss: 0.0005542919388972223
# Epoch 8900, Loss: 0.0005785257089883089
# Epoch 9000, Loss: 0.0005464291898533702
# Epoch 9100, Loss: 0.0005414644256234169
# Epoch 9200, Loss: 0.0005365315009839833
# Epoch 9300, Loss: 0.0005315078306011856
# Epoch 9400, Loss: 0.000541434099432081
# Epoch 9500, Loss: 0.0005225987988524139
# Epoch 9600, Loss: 0.0005172305973246694
# Epoch 9700, Loss: 0.00051178561989218
# Epoch 9800, Loss: 0.00050618831301108
# Epoch 9900, Loss: 0.0006660327198915184
# Epoch 10000, Loss: 0.0004947450943291187

# %%
# Training

# %%
# Compute final MSE loss
model_psi.eval()
with torch.no_grad():
  Y_final = model_psi(X_train)
  loss = fn_Loss(Y_final, Y_train)
  loss_psi_vanilla = loss.item() * 100
  print(f"Final MSE Loss for (R, Z) -> psi (in %): {loss_psi_vanilla}")
# Out:
# Final MSE Loss for (R, Z) -> psi (in %): 0.04946819972246885

# %%
psi = Y_final.reshape(129,129)

# %%
def plot(R ,Z, psi_preds, title):
  plt.contourf(R, Z, psi_preds,  cmap = 'plasma')
  plt.colorbar()
  plt.xlim([R[0],R[-1]])
  plt.ylim([Z[0],Z[-1]])
  plt.xlabel('R [m]')
  plt.ylabel('Z [m]')
  plt.axis('equal')
  plt.title(title)

# %%
fig = plt.figure(figsize=(12, 4))

plt.subplot(1,3,1)
plot(g.r_grid[:, 0] ,g.z_grid[0, :], psi_norm.T, title = r"$\psi(R,Z)_{Normalized}$")

plt.subplot(1,3,2)
plot(g.r_grid[:, 0] ,g.z_grid[0, :], psi.T, title = r"$\psi(R,Z)_{predicted}$")

plt.subplot(1,3,3)
plot(g.r_grid[:, 0], g.z_grid[0, :], (abs(psi-psi_norm)*100).T, title=r"$\psi(R, Z)_{error}$")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3410/3372260933.py:10: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   plot(g.r_grid[:, 0], g.z_grid[0, :], (abs(psi-psi_norm)*100).T, title=r"$\psi(R, Z)_{error}$")
